# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data = []
# x=[0,1,4,7,10,13,16,19,22,25,28,31]
# for i in x:
#     ckpt = []
#     with open("/mnt/c/Users/owenb/OneDrive/Documents/GitHub/MINERVA_tf2/output/nell/d088_conv_NELL995_paper/checkpoint_sl_epoch_"+str(i)+"/scores.txt","r") as scores:
#         chunk = scores.read()
#         ckpt.append(float(chunk.split("Hits@1:  ")[1].split("\nHits@3")[0])-0.644)
#         ckpt.append(float(chunk.split("\nHits@3:  ")[1].split("\nHits@5")[0])-0.7982)
#         ckpt.append(float(chunk.split("\nHits@5:  ")[1].split("\nHits@10")[0])-0.8163)
#         ckpt.append(float(chunk.split("\nHits@10:  ")[1].split("\nHits@20")[0])-0.8231)
#         ckpt.append(float(chunk.split("\nHits@20:  ")[1].split("\nauc")[0])-0.8390)
#         ckpt.append(float(chunk.split("\nauc:  ")[1])-0.7219)
#     data.append(ckpt)
x=[0,2,3,4,5,6,7]
for i in x:
    ckpt = []
    with open("/mnt/c/Users/owenb/OneDrive/Documents/GitHub/MINERVA_tf2/output/fb15k-237/ca0f_conv_FB15K-237_paper/checkpoint_sl_epoch_"+str(i)+"/scores.txt","r") as scores:
        chunk = scores.read()
        chunk = chunk.split("Hits@1:  ")[-1]
        ckpt.append(float(chunk.split("\nHits@3")[0]))
        ckpt.append(float(chunk.split("\nHits@3:  ")[1].split("\nHits@5")[0]))
        ckpt.append(float(chunk.split("\nHits@5:  ")[1].split("\nHits@10")[0]))
        ckpt.append(float(chunk.split("\nHits@10:  ")[1].split("\nHits@20")[0]))
        ckpt.append(float(chunk.split("\nHits@20:  ")[1].split("\nauc")[0]))
        ckpt.append(float(chunk.split("\nauc:  ")[1])-0.2914)
    data.append(ckpt)
data = np.array(data)
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(data, annot=True, linewidths=.5, ax=ax, xticklabels=['Hits@1','Hits@3','Hits@5','Hits@10','Hits@20','auc'], yticklabels=x)#,'no mask','20% mask','40% mask'
# Out:
# <AxesSubplot:>
